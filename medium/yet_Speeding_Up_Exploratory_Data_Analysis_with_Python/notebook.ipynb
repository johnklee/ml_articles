# %% [markdown]
# ## <font color='darkblue'>Preface</font>
# ([article source](https://towardsdatascience.com/speeding-up-exploratory-data-analysis-with-python-838fe5e25b43)) <font size='3ptx'><b>Increasing Productivity with Open-Source EDA Libraries</b></font>
#
# <b><font color='darkblue'>Exploratory Data Analysis</font></b> (EDA) — especially when done for take-home home job interviews — can be a very time consuming process. <b>EDA’s main purpose is to investigate and learn about a new dataset. We want to gain insights and familiarity with the data — ideally as quickly as possible.</b>
#
# The instructions for take-home assignments often come with an instruction stating to take no more than 4 or 6 hours to complete. <font color='darkred'><b>When on the job, the boss may be waiting impatiently for our analysis</b></font>.
#
# Here we will explore 3 open-source libraries that can help speed up EDA process:
# * <font size='3ptx'><b><a href='#sect1'>DataPrep</a></b></font>
# * Pandas Profiling
# * SweetViz
# <br/><br/>
#
# In <b><a href='https://towardsdatascience.com/tackling-the-take-home-challenge-7c2148fb999e'>“Tackling the Take-Home Challenge”</a></b> we worked through a sample take-home EDA challenge using Python, Pandas, and Seaborn. The notebook was time consuming to create and we used a lot of code. <b>Let’s see if we can speed up our analysis with the help of the above libraries</b>.

# %% [markdown]
# ### <font color='darkgreen'>Dataset</font>
# We’ll continue using the widget factory datasets we created in [this article](https://towardsdatascience.com/generating-fake-data-with-python-c7a32c631b2a), where we worked through generating fake data with Python.

# %%
#!pip install faker
# !pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (12.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.4->faker) (1.12.0)

# %%
import pandas as pd
import numpy as np
import faker

# create some fake data
fake = faker.Faker()

# function to create a dataframe with fake values for our workers
def make_workers(num):
    
    # lists to randomly assign to workers
    status_list = ['Full Time', 'Part Time', 'Per Diem']
    team_list = [fake.color_name() for x in range(4)]
    

    fake_workers = [
        {
            'Worker ID':x+1000,
            'Worker Name':fake.name(), 
            'Hire Date':fake.date_between(start_date='-30y', end_date='today'),
            'Worker Status':np.random.choice(status_list, p=[0.50, 0.30, 0.20]), # assign items from list with different probabilities
            'Team':np.random.choice(team_list)
        } for x in range(num)]
        
    return fake_workers

worker_df = pd.DataFrame(make_workers(num=5000))
worker_df.head()
# Out:
#    Worker ID       Worker Name   Hire Date Worker Status       Team
# 0       1000  Kaitlyn Anderson  1993-02-27     Full Time  Gainsboro
# 1       1001   Melanie Hensley  2013-10-17      Per Diem        Red
# 2       1002        Nathan Fox  2007-05-02     Full Time  SteelBlue
# 3       1003   Amanda Mitchell  2007-05-04     Full Time  SteelBlue
# 4       1004   Bonnie Melendez  2000-03-13      Per Diem  Gainsboro

# %% [markdown]
# <a id='sect1'></a>
# ## <font color='darkblue'>DataPrep</font>
# <font size='3ptx'><b><a href='https://dataprep.ai/'>DataPrep</a> bills itself as “the fastest and the easiest EDA tool in Python. It allows data scientists to understand a Pandas/Dask DataFrame with a few lines of code in seconds.”</b></font>
#
# It is indeed very easy to use and can reduce the EDA process to just a few lines of code. DataPrep is easy to install with pip:

# %%
# !pip install dataprep
# Out:
# Collecting dataprep
#   Using cached dataprep-0.4.1-py3-none-any.whl (3.5 MB)
# Collecting flask_cors<4.0.0,>=3.0.10
#   Using cached Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting levenshtein<0.13.0,>=0.12.0
#   Using cached levenshtein-0.12.0-cp38-cp38-win_amd64.whl (82 kB)
# Collecting jsonpath-ng<2.0,>=1.5
#   Using cached jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting metaphone<0.7,>=0.6
#   Using cached Metaphone-0.6-py3-none-any.whl
# Collecting usaddress<0.6.0,>=0.5.10
#   Using cached usaddress-0.5.10-py2.py3-none-any.whl (63 kB)
# Collecting jinja2<3.0,>=2.11
#   Using cached Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Collecting varname<0.9.0,>=0.8.1
#   Using cached varname-0.8.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas<2.0,>=1.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dataprep) (1.3.5)
# Collecting regex<2021.0.0,>=2020.10.15
#   Using cached regex-2020.11.13-cp38-cp38-win_amd64.whl (270 kB)
# Requirement already satisfied: wordcloud<2.0,>=1.8 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dataprep) (1.8.1)
# Collecting dask[array,dataframe,delayed]<3.0,>=2.25
#   Using cached dask-2.30.0-py3-none-any.whl (848 kB)
# Requirement already satisfied: nltk<4.0,>=3.5 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dataprep) (3.6.2)
# Collecting aiohttp<4.0,>=3.6
#   Using cached aiohttp-3.8.1-cp38-cp38-win_amd64.whl (555 kB)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dataprep) (7.6.2)
# Collecting flask<2.0.0,>=1.1.4
#   Using cached Flask-1.1.4-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: pydantic<2.0,>=1.6 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dataprep) (1.8.2)
# Requirement already satisfied: tqdm<5.0,>=4.48 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dataprep) (4.57.0)
# Collecting bottleneck<2.0,>=1.3
#   Using cached Bottleneck-1.3.2.tar.gz (88 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting python-stdnum<2.0,>=1.16
#   Using cached python_stdnum-1.17-py2.py3-none-any.whl (943 kB)
# Requirement already satisfied: bokeh<3,>=2 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dataprep) (2.3.0)
# Requirement already satisfied: scipy<2,>=1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dataprep) (1.5.4)
# Requirement already satisfied: numpy<2,>=1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dataprep) (1.19.5)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.0-cp38-cp38-win_amd64.whl (33 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.7.2-cp38-cp38-win_amd64.whl (122 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.0.9)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (20.3.0)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.2-cp38-cp38-win_amd64.whl (28 kB)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from bokeh<3,>=2->dataprep) (2.8.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from bokeh<3,>=2->dataprep) (20.8)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from bokeh<3,>=2->dataprep) (5.3.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from bokeh<3,>=2->dataprep) (8.1.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from bokeh<3,>=2->dataprep) (3.7.4.3)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dask[array,dataframe,delayed]<3.0,>=2.25->dataprep) (1.6.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dask[array,dataframe,delayed]<3.0,>=2.25->dataprep) (0.11.1)
# Requirement already satisfied: partd>=0.3.10 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dask[array,dataframe,delayed]<3.0,>=2.25->dataprep) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from dask[array,dataframe,delayed]<3.0,>=2.25->dataprep) (2021.11.1)
# Collecting Werkzeug<2.0,>=0.15
#   Using cached Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting itsdangerous<2.0,>=0.24
#   Using cached itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: click<8.0,>=5.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from flask<2.0.0,>=1.1.4->dataprep) (7.1.2)
# Requirement already satisfied: Six in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.4.2)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (7.19.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.0.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from jinja2<3.0,>=2.11->dataprep) (2.0.1)
# Collecting ply
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: decorator in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (4.4.2)
# Requirement already satisfied: setuptools in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from levenshtein<0.13.0,>=0.12.0->dataprep) (49.2.1)
# Requirement already satisfied: joblib in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nltk<4.0,>=3.5->dataprep) (1.0.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2021.1)
# Requirement already satisfied: python-crfsuite>=0.7 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from usaddress<0.6.0,>=0.5.10->dataprep) (0.9.7)
# Collecting probableparsing
#   Using cached probableparsing-0.0.1-py2.py3-none-any.whl (3.1 kB)
# Requirement already satisfied: future>=0.14 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from usaddress<0.6.0,>=0.5.10->dataprep) (0.18.2)
# Collecting executing
#   Using cached executing-0.8.2-py2.py3-none-any.whl (16 kB)
# Collecting pure_eval<1.0.0
#   Using cached pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Collecting asttokens<3.0.0,>=2.0.0
#   Using cached asttokens-2.0.5-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: matplotlib in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.3.2)
# Requirement already satisfied: jupyter-client in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (6.1.7)
# Requirement already satisfied: backcall in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.8)
# Requirement already satisfied: pygments in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.7.3)
# Requirement already satisfied: pickleshare in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: colorama in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.4.4)
# Requirement already satisfied: ipython-genutils in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (3.2.0)
# Requirement already satisfied: jupyter-core in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.7.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from packaging>=16.8->bokeh<3,>=2->dataprep) (2.4.7)
# Requirement already satisfied: locket in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from partd>=0.3.10->dask[array,dataframe,delayed]<3.0,>=2.25->dataprep) (0.2.1)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.3.0)
# Requirement already satisfied: idna>=2.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (2.8)
# Requirement already satisfied: cycler>=0.10 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.3.1)
# Requirement already satisfied: certifi>=2020.06.20 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (2020.12.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.17.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.9.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: nbconvert in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.0.7)
# Requirement already satisfied: pyzmq>=17 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (20.0.0)
# Requirement already satisfied: prometheus-client in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.9.0)
# Requirement already satisfied: argon2-cffi in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (20.1.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (227)
# Requirement already satisfied: wcwidth in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.14.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.4.3)
# Requirement already satisfied: bleach in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (3.2.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: testpath in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.4.4)
# Requirement already satisfied: pycparser in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.20)
# Requirement already satisfied: nest-asyncio in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.4.3)
# Requirement already satisfied: async-generator in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.10)
# Requirement already satisfied: webencodings in c:\users\john\appdata\local\programs\python\python38\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Building wheels for collected packages: bottleneck
#   Building wheel for bottleneck (pyproject.toml): started
#   Building wheel for bottleneck (pyproject.toml): finished with status 'error'
# Failed to build bottleneck
#   error: subprocess-exited-with-error
#
#   Building wheel for bottleneck (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [19 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   UPDATING build\lib.win-amd64-3.8\bottleneck/_version.py
#   set build\lib.win-amd64-3.8\bottleneck/_version.py to '1.3.2'
#   running build_ext
#   running config
#   compiling '_configtest.c':
#
#
#
#   int __attribute__((optimize("O3"))) have_attribute_optimize_opt_3(void*);
#
#   int main(void)
#   {
#       return 0;
#   }
#
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for bottleneck
# ERROR: Could not build wheels for bottleneck, which is required to install pyproject.toml-based projects

# %% [markdown]
# We can use the <font color='blue'>plot()</font> method to visualize our entire dataframe and to show key insights:

# %%
from dataprep.eda import plot

# using dataprep's plot method to get insights on each variable
plot(worker_df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-6a438ba23a69> in <module>
# ----> 1 from dataprep.eda import plot
#       2
#       3 # using dataprep's plot method to get insights on each variable
#       4 plot(worker_df)
#
# ModuleNotFoundError: No module named 'dataprep'
